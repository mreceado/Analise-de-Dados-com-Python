# %% [markdown]
# ### Prática2 Pandas_Dataframe

# %%
import pandas as pd
import datetime as dt

# %%
df = pd.read_csv('dataset2.csv')

# %%
df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# ...

# %%
df.shape
# Out:
# (9994, 11)

# %%
df.tail()
# Out:
#            ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 9989  CA-2014-110422  2014-01-21   TB-21400  Consumer  United States  South
# 9990  CA-2017-121258  2017-02-26   DB-13060  Consumer  United States   West
# 9991  CA-2017-121258  2017-02-26   DB-13060  Consumer  United States   West
# 9992  CA-2017-121258  2017-02-26   DB-13060  Consumer  United States   West
# 9993  CA-2017-119914  2017-05-04   CC-12220  Consumer  United States   West
#
#            ID_Produto        Categoria  \
# 9989  FUR-FU-10001889        Furniture
# 9990  FUR-FU-10000747        Furniture
# 9991  TEC-PH-10003645       Technology
# 9992  OFF-PA-10004041  Office Supplies
# 9993  OFF-AP-10002684  Office Supplies
#
#                                            Nome_Produto  Valor_Venda  \
# 9989                             Ultra Door Pull Handle       25.248
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...       91.960
# ...

# %%
df.columns
# Out:
# Index(['ID_Pedido', 'Data_Pedido', 'ID_Cliente', 'Segmento', 'Pais', 'Regiao',
#        'ID_Produto', 'Categoria', 'Nome_Produto', 'Valor_Venda', 'Quantidade'],
#       dtype='object')

# %%
# Exibe informações gerais
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID_Pedido     9994 non-null   object
#  1   Data_Pedido   9994 non-null   object
#  2   ID_Cliente    9994 non-null   object
#  3   Segmento      9994 non-null   object
#  4   Pais          9994 non-null   object
#  5   Regiao        9994 non-null   object
#  6   ID_Produto    9994 non-null   object
#  7   Categoria     9994 non-null   object
#  8   Nome_Produto  9994 non-null   object
#  9   Valor_Venda   9994 non-null   float64
#  10  Quantidade    9992 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 859.0+ KB

# %%
# Exibe resumo estatístico
df.describe()
# Out:
#         Valor_Venda   Quantidade
# count   9994.000000  9992.000000
# mean     229.858001     3.789832
# std      623.245101     2.225246
# min        0.444000     1.000000
# 25%       17.280000     2.000000
# 50%       54.490000     3.000000
# 75%      209.940000     5.000000
# max    22638.480000    14.000000

# %%
# Método loc, utilizado para visualizar informações no dataset
# Visualizar os dados da "Região" "West"
nomeProd = df.loc[df["Regiao"] == "West"]
nomeProd.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 5  CA-2014-115812  2014-06-09   BH-11710   Consumer  United States   West
# 6  CA-2014-115812  2014-06-09   BH-11710   Consumer  United States   West
# 7  CA-2014-115812  2014-06-09   BH-11710   Consumer  United States   West
# 8  CA-2014-115812  2014-06-09   BH-11710   Consumer  United States   West
#
#         ID_Produto        Categoria  \
# 2  OFF-LA-10000240  Office Supplies
# 5  FUR-FU-10001487        Furniture
# 6  OFF-AR-10002833  Office Supplies
# 7  TEC-PH-10002275       Technology
# 8  OFF-BI-10003910  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 2  Self-Adhesive Address Labels for Typewriters b...       14.620         2.0
# 5  Eldon Expressions Wood and Plastic Desk Access...       48.860         7.0
# ...

# %%
# Agrupar os dados por uma determinada coluna
df.groupby("Regiao")["Pais"].nunique()
# Out:
# Regiao
# Central    1
# East       1
# South      1
# West       1
# Name: Pais, dtype: int64

# %%
# A Quantidade por Segmento
df.groupby('Segmento')['Quantidade'].sum()
# Out:
# Segmento
# Consumer       19516.0
# Corporate      11608.0
# Home Office     6744.0
# Name: Quantidade, dtype: float64

# %%
# A média de qtd por segmento
df.groupby('Segmento')['Quantidade'].mean()
# Out:
# Segmento
# Consumer       3.761033
# Corporate      3.843709
# Home Office    3.782389
# Name: Quantidade, dtype: float64

# %%
# Multiplicação de colunas
df['Receita'] = df['Valor_Venda'].mul(df['Quantidade'])

# %%
df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# ...

# %%
df.isna().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      2
# Receita         2
# dtype: int64

# %%
# Moda - valor que mais aparece
moda_Qtd = df['Quantidade'].value_counts().index[0]

# %%
# Preenchendo os valores ausentes em quantidade
df['Quantidade'].fillna(value=moda_Qtd, inplace = True)

# %%
# Percorre a coluna Receita e encontra  o valor que mais aparece
moda_Rec = df['Receita'].value_counts().index[0]

# %%
# preenche os valores ausentes da coluna Receita
df['Receita'].fillna(value = moda_Rec, inplace = True)

# %%
df.isna().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      0
# Receita         0
# dtype: int64

# %%
df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
df.isnull().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      0
# Receita         0
# dtype: int64

# %%
# O método sort_values() para ordenar o nosso dataset pelos parâmetros definidos

# Ordenar o dataset por receitas, de modo decrescente
df.sort_values(by = "Receita", ascending = False).head(10)
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 2697  CA-2014-145317  2014-03-18   SM-20320  Home Office  United States
# 9039  CA-2016-117121  2016-12-17   AB-10105     Consumer  United States
# 6826  CA-2016-118689  2016-10-02   TC-20980    Corporate  United States
# 165   CA-2014-139892  2014-09-08   BM-11140     Consumer  United States
# 4277  US-2016-107440  2016-04-16   BS-11365    Corporate  United States
# 4297  CA-2017-129021  2017-08-23   PO-18850     Consumer  United States
# 8153  CA-2017-140151  2017-03-23   RB-19360     Consumer  United States
# 9639  CA-2015-116638  2015-01-28   JH-15985     Consumer  United States
# 7666  US-2016-140158  2016-10-04   DR-12940  Home Office  United States
# 4098  CA-2014-116904  2014-09-23   SC-20095     Consumer  United States
#
#        Regiao       ID_Produto        Categoria  \
# 2697    South  TEC-MA-10002412       Technology
# 9039  Central  OFF-BI-10000545  Office Supplies
# ...

# %%
# Utilizar o value_counts para retornar a qtd de vendas que cada região fez
df['Regiao'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Regiao, dtype: int64

# %%
# O gráfico em barras
df['Regiao'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
# Grafico horizontal
df['Regiao'].value_counts().plot.barh()
# Out:
# <Axes: >

# %%
# %matplotlib inline
df['Regiao'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='Regiao'>

# %%
# Convertendo data_pedido em datetime
df['Data_Pedido'] = pd.to_datetime(df['Data_Pedido'], dayfirst= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID_Pedido     9994 non-null   object
#  1   Data_Pedido   9994 non-null   datetime64[ns]
#  2   ID_Cliente    9994 non-null   object
#  3   Segmento      9994 non-null   object
#  4   Pais          9994 non-null   object
#  5   Regiao        9994 non-null   object
#  6   ID_Produto    9994 non-null   object
#  7   Categoria     9994 non-null   object
#  8   Nome_Produto  9994 non-null   object
#  9   Valor_Venda   9994 non-null   float64
#  10  Quantidade    9994 non-null   float64
#  11  Receita       9994 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(8)
# memory usage: 937.1+ KB

# %%
# Mostrar o resumo das receitas por ano
df.groupby(df['Data_Pedido'].dt.year)['Valor_Venda'].sum()
# Out:
# Data_Pedido
# 2014    484247.4981
# 2015    470532.5090
# 2016    609205.5980
# 2017    733215.2552
# Name: Valor_Venda, dtype: float64

# %%
# Plot
df.groupby(df['Data_Pedido'].dt.year)['Valor_Venda'].sum().plot.bar();

# %%
# Criar uma coluna com o ano
df['Ano'] = df['Data_Pedido'].dt.year

# %%
df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
# Criar as colunas Mês e Dia
df['Mes'], df['Dia'] = (df['Data_Pedido'].dt.month, df['Data_Pedido'].dt.day)

# %%
df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
# Qual é a data mais antiga do nosso dataset
data_mais_antiga = df['Data_Pedido'].min()
data_mais_antiga
# Out:
# Timestamp('2014-01-03 00:00:00')

# %%
# Calculando a diferença de dias
diferenca_de_dias = df['Data_Pedido'] - df['Data_Pedido'].min()
diferenca_de_dias.head()
# Out:
# 0   1040 days
# 1   1040 days
# 2    891 days
# 3    646 days
# 4    646 days
# Name: Data_Pedido, dtype: timedelta64[ns]

# %%
# Calcular o semestre
semestre_Venda = df['Data_Pedido'].dt.quarter
semestre_Venda.head()
# Out:
# 0    4
# 1    4
# 2    2
# 3    4
# 4    4
# Name: Data_Pedido, dtype: int64

# %%
# Usando a função loc para obter todas as vendas do mês de Março do ano de 2019
#vendas_Marco_2019 = df.loc[(df['Ano'] == 2019) & (df['Data_Pedido'].dt.month == 3)]
vendas_Marco_2019 = df.loc[df['Ano'] == 2019]
vendas_Marco_2019
# Out:
# Empty DataFrame
# Columns: [ID_Pedido, Data_Pedido, ID_Cliente, Segmento, Pais, Regiao, ID_Produto, Categoria, Nome_Produto, Valor_Venda, Quantidade, Receita, Ano, Mes, Dia]
# Index: []
